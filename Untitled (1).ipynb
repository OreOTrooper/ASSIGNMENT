# %%
import pandas as pd 
d1=pd.read_csv('/content/Salary_Data.csv')
#print(d)
import numpy as np
y = d1['YearsExperience']
x=d1['Salary']
summation = 0  
n = len(y)
#for i in range(0,1000):
yp=[]
def mse(b0,b1):
  for i in range (0,n):
    y_bar =(b1*x[i])+b0
    dif =(y[i]-y_bar)**2 
    yp.append(dif)
    ypp=np.array(yp)
    MSE = np.mean(ypp)
    print("The Mean Square Error for b0=",b0,"b1=",b1,"is: ",MSE)

# %%
for i in range(0,10):
  mse(i,i+1)
# Out:
# The Mean Square Error for b0= 0 b1= 1 is:  180772318475806.34
# The Mean Square Error for b0= 0 b1= 1 is:  180751427434122.06
# The Mean Square Error for b0= 0 b1= 1 is:  180730541138314.47
# The Mean Square Error for b0= 0 b1= 1 is:  180709659723307.34
# The Mean Square Error for b0= 0 b1= 1 is:  180688783098006.2
# The Mean Square Error for b0= 0 b1= 1 is:  180667911482537.72
# The Mean Square Error for b0= 0 b1= 1 is:  180647044735734.66
# The Mean Square Error for b0= 0 b1= 1 is:  180626182733098.53
# The Mean Square Error for b0= 0 b1= 1 is:  180605325685755.88
# The Mean Square Error for b0= 0 b1= 1 is:  180584473352823.5
# The Mean Square Error for b0= 0 b1= 1 is:  180563625918359.16
# The Mean Square Error for b0= 0 b1= 1 is:  180542783194892.2
# The Mean Square Error for b0= 0 b1= 1 is:  180521945297898.78
# The Mean Square Error for b0= 0 b1= 1 is:  180501112212206.3
# The Mean Square Error for b0= 0 b1= 1 is:  180480283989472.88
# The Mean Square Error for b0= 0 b1= 1 is:  180459460674706.12
# The Mean Square Error for b0= 0 b1= 1 is:  180438642135075.38
# The Mean Square Error for b0= 0 b1= 1 is:  180417828691840.88
# The Mean Square Error for b0= 0 b1= 1 is:  180397020017133.34
# The Mean Square Error for b0= 0 b1= 1 is:  180376216396279.84
# The Mean Square Error for b0= 0 b1= 1 is:  180355417526148.0
# The Mean Square Error for b0= 0 b1= 1 is:  180334623595404.44
# The Mean Square Error for b0= 0 b1= 1 is:  180313834528872.2
# The Mean Square Error for b0= 0 b1= 1 is:  180293050565388.16
# The Mean Square Error for b0= 0 b1= 1 is:  180272271280311.44
# The Mean Square Error for b0= 0 b1= 1 is:  180251496689367.3
# The Mean Square Error for b0= 0 b1= 1 is:  180230727178285.9
# The Mean Square Error for b0= 0 b1= 1 is:  180209962338707.88
# The Mean Square Error for b0= 0 b1= 1 is:  180189202547774.34
# The Mean Square Error for b0= 0 b1= 1 is:  180168447525043.94
# The Mean Square Error for b0= 1 b1= 2 is:  180147696286152.7
# The Mean Square Error for b0= 1 b1= 2 is:  180126950097423.72
# The Mean Square Error for b0= 1 b1= 2 is:  180106208359093.5
# The Mean Square Error for b0= 1 b1= 2 is:  180085471614035.3
# The Mean Square Error for b0= 1 b1= 2 is:  180064739504129.9
# The Mean Square Error for b0= 1 b1= 2 is:  180044012911903.62
# The Mean Square Error for b0= 1 b1= 2 is:  180023291279617.34
# The Mean Square Error for b0= 1 b1= 2 is:  180002574115993.62
# The Mean Square Error for b0= 1 b1= 2 is:  179981862267656.34
# The Mean Square Error for b0= 1 b1= 2 is:  179961154779385.9
# The Mean Square Error for b0= 1 b1= 2 is:  179940452389895.47
# The Mean Square Error for b0= 1 b1= 2 is:  179919754356859.97
# The Mean Square Error for b0= 1 b1= 2 is:  179899061145606.12
# The Mean Square Error for b0= 1 b1= 2 is:  179878372700650.28
# The Mean Square Error for b0= 1 b1= 2 is:  179857689232925.0
# The Mean Square Error for b0= 1 b1= 2 is:  179837010926841.84
# The Mean Square Error for b0= 1 b1= 2 is:  179816337257872.6
# The Mean Square Error for b0= 1 b1= 2 is:  179795669511669.16
# The Mean Square Error for b0= 1 b1= 2 is:  179775006386226.0
# The Mean Square Error for b0= 1 b1= 2 is:  179754349023926.2
# The Mean Square Error for b0= 1 b1= 2 is:  179733696221385.47
# The Mean Square Error for b0= 1 b1= 2 is:  179713048735657.62
# The Mean Square Error for b0= 1 b1= 2 is:  179692406272060.34
# The Mean Square Error for b0= 1 b1= 2 is:  179671769787641.72
# The Mean Square Error for b0= 1 b1= 2 is:  179651137594604.34
# The Mean Square Error for b0= 1 b1= 2 is:  179630509760592.84
# The Mean Square Error for b0= 1 b1= 2 is:  179609887828260.56
# The Mean Square Error for b0= 1 b1= 2 is:  179589270174668.88
# The Mean Square Error for b0= 1 b1= 2 is:  179568658308250.94
# The Mean Square Error for b0= 1 b1= 2 is:  179548051115988.1
# The Mean Square Error for b0= 2 b1= 3 is:  179527443434622.3
# The Mean Square Error for b0= 2 b1= 3 is:  179506841089950.88
# The Mean Square Error for b0= 2 b1= 3 is:  179486242739213.97
# The Mean Square Error for b0= 2 b1= 3 is:  179465649601760.3
# The Mean Square Error for b0= 2 b1= 3 is:  179445060876654.44
# The Mean Square Error for b0= 2 b1= 3 is:  179424478544850.25
# The Mean Square Error for b0= 2 b1= 3 is:  179403901357800.1
# The Mean Square Error for b0= 2 b1= 3 is:  179383328215991.7
# The Mean Square Error for b0= 2 b1= 3 is:  179362761019861.2
# The Mean Square Error for b0= 2 b1= 3 is:  179342197629611.5
# The Mean Square Error for b0= 2 b1= 3 is:  179321639703710.25
# The Mean Square Error for b0= 2 b1= 3 is:  179301085579711.72
# The Mean Square Error for b0= 2 b1= 3 is:  179280536303076.62
# The Mean Square Error for b0= 2 b1= 3 is:  179259991751459.78
# The Mean Square Error for b0= 2 b1= 3 is:  179239452399903.56
# The Mean Square Error for b0= 2 b1= 3 is:  179218918663976.5
# The Mean Square Error for b0= 2 b1= 3 is:  179198389369586.9
# The Mean Square Error for b0= 2 b1= 3 is:  179177867401609.7
# The Mean Square Error for b0= 2 b1= 3 is:  179157349842633.1
# The Mean Square Error for b0= 2 b1= 3 is:  179136839256264.47
# The Mean Square Error for b0= 2 b1= 3 is:  179116332946237.84
# The Mean Square Error for b0= 2 b1= 3 is:  179095832612136.06
# The Mean Square Error for b0= 2 b1= 3 is:  179075337595266.22
# The Mean Square Error for b0= 2 b1= 3 is:  179054850043659.25
# The Mean Square Error for b0= 2 b1= 3 is:  179034366174823.5
# The Mean Square Error for b0= 2 b1= 3 is:  179013886142480.53
# The Mean Square Error for b0= 2 b1= 3 is:  178993413407794.88
# The Mean Square Error for b0= 2 b1= 3 is:  178972944333672.56
# The Mean Square Error for b0= 2 b1= 3 is:  178952482304563.1
# The Mean Square Error for b0= 2 b1= 3 is:  178932024826761.84
# The Mean Square Error for b0= 3 b1= 4 is:  178911559571867.97
# The Mean Square Error for b0= 3 b1= 4 is:  178891100072781.72
# The Mean Square Error for b0= 3 b1= 4 is:  178870643951834.06
# The Mean Square Error for b0= 3 b1= 4 is:  178850193370611.25
# The Mean Square Error for b0= 3 b1= 4 is:  178829746911379.0
# The Mean Square Error for b0= 3 b1= 4 is:  178809308085060.53
# The Mean Square Error for b0= 3 b1= 4 is:  178788874680885.3
# The Mean Square Error for b0= 3 b1= 4 is:  178768444752134.66
# The Mean Square Error for b0= 3 b1= 4 is:  178748021667068.72
# The Mean Square Error for b0= 3 b1= 4 is:  178727601635908.88
# The Mean Square Error for b0= 3 b1= 4 is:  178707187598221.16
# The Mean Square Error for b0= 3 b1= 4 is:  178686776609929.44
# The Mean Square Error for b0= 3 b1= 4 is:  178666370524543.56
# The Mean Square Error for b0= 3 b1= 4 is:  178645969126579.22
# The Mean Square Error for b0= 3 b1= 4 is:  178625573258946.62
# The Mean Square Error for b0= 3 b1= 4 is:  178605183659181.66
# The Mean Square Error for b0= 3 b1= 4 is:  178584798248413.53
# The Mean Square Error for b0= 3 b1= 4 is:  178564422139048.84
# The Mean Square Error for b0= 3 b1= 4 is:  178544050163589.66
# The Mean Square Error for b0= 3 b1= 4 is:  178523686865240.1
# The Mean Square Error for b0= 3 b1= 4 is:  178503327468312.03
# The Mean Square Error for b0= 3 b1= 4 is:  178482974985215.94
# The Mean Square Error for b0= 3 b1= 4 is:  178462628250228.12
# The Mean Square Error for b0= 3 b1= 4 is:  178442291070280.25
# The Mean Square Error for b0= 3 b1= 4 is:  178421956745187.84
# The Mean Square Error for b0= 3 b1= 4 is:  178401625548555.78
# The Mean Square Error for b0= 3 b1= 4 is:  178381303613829.53
# The Mean Square Error for b0= 3 b1= 4 is:  178360984498392.28
# The Mean Square Error for b0= 3 b1= 4 is:  178340674199790.7
# The Mean Square Error for b0= 3 b1= 4 is:  178320368301151.75
# The Mean Square Error for b0= 4 b1= 5 is:  178300044353321.28
# The Mean Square Error for b0= 4 b1= 5 is:  178279726711630.28
# The Mean Square Error for b0= 4 b1= 5 is:  178259411674582.28
# The Mean Square Error for b0= 4 b1= 5 is:  178239102609036.6
# The Mean Square Error for b0= 4 b1= 5 is:  178218797308262.4
# The Mean Square Error for b0= 4 b1= 5 is:  178198501240268.66
# The Mean Square Error for b0= 4 b1= 5 is:  178178210963431.56
# The Mean Square Error for b0= 4 b1= 5 is:  178157923447304.75
# The Mean Square Error for b0= 4 b1= 5 is:  178137643937739.7
# The Mean Square Error for b0= 4 b1= 5 is:  178117366534343.38
# The Mean Square Error for b0= 4 b1= 5 is:  178097095815420.25
# The Mean Square Error for b0= 4 b1= 5 is:  178076827197458.88
# The Mean Square Error for b0= 4 b1= 5 is:  178056563567597.62
# The Mean Square Error for b0= 4 b1= 5 is:  178036304591204.84
# The Mean Square Error for b0= 4 b1= 5 is:  178016051581753.56
# The Mean Square Error for b0= 4 b1= 5 is:  177995805688627.72
# The Mean Square Error for b0= 4 b1= 5 is:  177975563675576.5
# The Mean Square Error for b0= 4 b1= 5 is:  177955333504412.3
# The Mean Square Error for b0= 4 b1= 5 is:  177935107129371.8
# The Mean Square Error for b0= 4 b1= 5 is:  177914891625911.66
# The Mean Square Error for b0= 4 b1= 5 is:  177894679558386.8
# The Mean Square Error for b0= 4 b1= 5 is:  177874475618543.6
# The Mean Square Error for b0= 4 b1= 5 is:  177854277992072.22
# The Mean Square Error for b0= 4 b1= 5 is:  177834092607934.8
# The Mean Square Error for b0= 4 b1= 5 is:  177813909033678.62
# The Mean Square Error for b0= 4 b1= 5 is:  177793727696251.72
# The Mean Square Error for b0= 4 b1= 5 is:  177773558147438.88
# The Mean Square Error for b0= 4 b1= 5 is:  177753390355829.1
# The Mean Square Error for b0= 4 b1= 5 is:  177733233661608.16
# The Mean Square Error for b0= 4 b1= 5 is:  177713081187801.34
# The Mean Square Error for b0= 5 b1= 6 is:  177692897439111.6
# The Mean Square Error for b0= 5 b1= 6 is:  177672720676767.53
# The Mean Square Error for b0= 5 b1= 6 is:  177652545589480.94
# The Mean Square Error for b0= 5 b1= 6 is:  177632377009730.8
# The Mean Square Error for b0= 5 b1= 6 is:  177612211771352.22
# The Mean Square Error for b0= 5 b1= 6 is:  177592057722191.1
# The Mean Square Error for b0= 5 b1= 6 is:  177571909923886.34
# The Mean Square Error for b0= 5 b1= 6 is:  177551764028159.34
# The Mean Square Error for b0= 5 b1= 6 is:  177531627564033.66
# The Mean Square Error for b0= 5 b1= 6 is:  177511492064575.03
# The Mean Square Error for b0= 5 b1= 6 is:  177491364100813.0
# The Mean Square Error for b0= 5 b1= 6 is:  177471237095650.62
# The Mean Square Error for b0= 5 b1= 6 is:  177451115193129.94
# The Mean Square Error for b0= 5 b1= 6 is:  177430997913729.3
# The Mean Square Error for b0= 5 b1= 6 is:  177410887143131.34
# The Mean Square Error for b0= 5 b1= 6 is:  177390784531531.56
# The Mean Square Error for b0= 5 b1= 6 is:  177370685435277.06
# The Mean Square Error for b0= 5 b1= 6 is:  177350601281113.6
# The Mean Square Error for b0= 5 b1= 6 is:  177330520523245.06
# The Mean Square Error for b0= 5 b1= 6 is:  177310453316397.7
# The Mean Square Error for b0= 5 b1= 6 is:  177290388990358.84
# The Mean Square Error for b0= 5 b1= 6 is:  177270334278979.97
# The Mean Square Error for b0= 5 b1= 6 is:  177250286579254.56
# The Mean Square Error for b0= 5 b1= 6 is:  177230254400582.47
# The Mean Square Error for b0= 5 b1= 6 is:  177210222771975.62
# The Mean Square Error for b0= 5 b1= 6 is:  177190192306843.0
# The Mean Square Error for b0= 5 b1= 6 is:  177170176713760.47
# The Mean Square Error for b0= 5 b1= 6 is:  177150161597238.2
# The Mean Square Error for b0= 5 b1= 6 is:  177130160362206.1
# The Mean Square Error for b0= 5 b1= 6 is:  177110163140128.4
# The Mean Square Error for b0= 6 b1= 7 is:  177090118493985.94
# The Mean Square Error for b0= 6 b1= 7 is:  177070081642943.9
# The Mean Square Error for b0= 6 b1= 7 is:  177050045382871.88
# The Mean Square Error for b0= 6 b1= 7 is:  177030016269562.3
# The Mean Square Error for b0= 6 b1= 7 is:  177009990008715.2
# The Mean Square Error for b0= 6 b1= 7 is:  176989977246458.97
# The Mean Square Error for b0= 6 b1= 7 is:  176969971284519.84
# The Mean Square Error for b0= 6 b1= 7 is:  176949966225066.66
# The Mean Square Error for b0= 6 b1= 7 is:  176929972281745.88
# The Mean Square Error for b0= 6 b1= 7 is:  176909977969797.47
# The Mean Square Error for b0= 6 b1= 7 is:  176889992203358.8
# The Mean Square Error for b0= 6 b1= 7 is:  176870006061202.34
# The Mean Square Error for b0= 6 b1= 7 is:  176850025165275.84
# The Mean Square Error for b0= 6 b1= 7 is:  176830048865687.47
# The Mean Square Error for b0= 6 b1= 7 is:  176810079720941.75
# The Mean Square Error for b0= 6 b1= 7 is:  176790119970104.8
# The Mean Square Error for b0= 6 b1= 7 is:  176770163314643.12
# The Mean Square Error for b0= 6 b1= 7 is:  176750225255503.25
# The Mean Square Error for b0= 6 b1= 7 is:  176730290131413.84
# The Mean Square Error for b0= 6 b1= 7 is:  176710371717825.0
# The Mean Square Error for b0= 6 b1= 7 is:  176690455541189.94
# The Mean Square Error for b0= 6 b1= 7 is:  176670550736546.22
# The Mean Square Error for b0= 6 b1= 7 is:  176650653773505.1
# The Mean Square Error for b0= 6 b1= 7 is:  176630776195652.7
# The Mean Square Error for b0= 6 b1= 7 is:  176610897695394.34
# The Mean Square Error for b0= 6 b1= 7 is:  176591019105380.53
# The Mean Square Error for b0= 6 b1= 7 is:  176571159021926.5
# The Mean Square Error for b0= 6 b1= 7 is:  176551297918056.94
# The Mean Square Error for b0= 6 b1= 7 is:  176531453978215.06
# The Mean Square Error for b0= 6 b1= 7 is:  176511613816244.47
# The Mean Square Error for b0= 7 b1= 8 is:  176491707187231.1
# The Mean Square Error for b0= 7 b1= 8 is:  176471809289313.47
# The Mean Square Error for b0= 7 b1= 8 is:  176451910745343.06
# The Mean Square Error for b0= 7 b1= 8 is:  176432020089502.88
# The Mean Square Error for b0= 7 b1= 8 is:  176412131732369.38
# The Mean Square Error for b0= 7 b1= 8 is:  176392259532551.84
# The Mean Square Error for b0= 7 b1= 8 is:  176372394771360.72
# The Mean Square Error for b0= 7 b1= 8 is:  176352529772043.16
# The Mean Square Error for b0= 7 b1= 8 is:  176332677830246.06
# The Mean Square Error for b0= 7 b1= 8 is:  176312823996678.22
# The Mean Square Error for b0= 7 b1= 8 is:  176292979875412.7
# The Mean Square Error for b0= 7 b1= 8 is:  176273133854102.06
# The Mean Square Error for b0= 7 b1= 8 is:  176253293251360.38
# The Mean Square Error for b0= 7 b1= 8 is:  176233457221703.25
# The Mean Square Error for b0= 7 b1= 8 is:  176213629096049.7
# The Mean Square Error for b0= 7 b1= 8 is:  176193811789502.97
# The Mean Square Error for b0= 7 b1= 8 is:  176173997103680.0
# The Mean Square Error for b0= 7 b1= 8 is:  176154205216819.3
# The Mean Square Error for b0= 7 b1= 8 is:  176134415742971.62
# The Mean Square Error for b0= 7 b1= 8 is:  176114646614277.8
# The Mean Square Error for b0= 7 b1= 8 is:  176094878990855.22
# The Mean Square Error for b0= 7 b1= 8 is:  176075124764370.22
# The Mean Square Error for b0= 7 b1= 8 is:  176055379339772.06
# The Mean Square Error for b0= 7 b1= 8 is:  176035657743986.03
# The Mean Square Error for b0= 7 b1= 8 is:  176015933542824.7
# The Mean Square Error for b0= 7 b1= 8 is:  175996207820627.84
# The Mean Square Error for b0= 7 b1= 8 is:  175976504784996.22
# The Mean Square Error for b0= 7 b1= 8 is:  175956799017834.1
# The Mean Square Error for b0= 7 b1= 8 is:  175937114190630.53
# The Mean Square Error for b0= 7 b1= 8 is:  175917432878875.38
# The Mean Square Error for b0= 8 b1= 9 is:  175897663192596.84
# The Mean Square Error for b0= 8 b1= 9 is:  175877903299359.9
# The Mean Square Error for b0= 8 b1= 9 is:  175858141371657.25
# The Mean Square Error for b0= 8 b1= 9 is:  175838388174558.28
# The Mean Square Error for b0= 8 b1= 9 is:  175818636658217.5
# The Mean Square Error for b0= 8 b1= 9 is:  175798904303732.94
# The Mean Square Error for b0= 8 b1= 9 is:  175779180114132.16
# The Mean Square Error for b0= 8 b1= 9 is:  175759454406692.0
# The Mean Square Error for b0= 8 b1= 9 is:  175739743952418.0
# The Mean Square Error for b0= 8 b1= 9 is:  175720029895300.06
# The Mean Square Error for b0= 8 b1= 9 is:  175700326872667.78
# The Mean Square Error for b0= 8 b1= 9 is:  175680620237572.88
# The Mean Square Error for b0= 8 b1= 9 is:  175660919221844.12
# The Mean Square Error for b0= 8 b1= 9 is:  175641222759437.7
# The Mean Square Error for b0= 8 b1= 9 is:  175621535052272.9
# The Mean Square Error for b0= 8 b1= 9 is:  175601859777776.22
# The Mean Square Error for b0= 8 b1= 9 is:  175582186595221.78
# The Mean Square Error for b0= 8 b1= 9 is:  175562540957138.75
# The Mean Square Error for b0= 8 b1= 9 is:  175542897149852.3
# The Mean Square Error for b0= 8 b1= 9 is:  175523277792748.0
# The Mean Square Error for b0= 8 b1= 9 is:  175503659122292.53
# The Mean Square Error for b0= 8 b1= 9 is:  175484056138634.34
# The Mean Square Error for b0= 8 b1= 9 is:  175464463046168.03
# The Mean Square Error for b0= 8 b1= 9 is:  175444898799776.9
# The Mean Square Error for b0= 8 b1= 9 is:  175425330056670.78
# The Mean Square Error for b0= 8 b1= 9 is:  175405758184998.66
# The Mean Square Error for b0= 8 b1= 9 is:  175386213719889.97
# The Mean Square Error for b0= 8 b1= 9 is:  175366664600161.0
# The Mean Square Error for b0= 8 b1= 9 is:  175347140684739.5
# The Mean Square Error for b0= 8 b1= 9 is:  175327619995283.84
# The Mean Square Error for b0= 9 b1= 10 is:  175307986188221.06
# The Mean Square Error for b0= 9 b1= 10 is:  175288363360823.3
# The Mean Square Error for b0= 9 b1= 10 is:  175268736960681.56
# The Mean Square Error for b0= 9 b1= 10 is:  175249120233700.66
# The Mean Square Error for b0= 9 b1= 10 is:  175229504505981.6
# The Mean Square Error for b0= 9 b1= 10 is:  175209911286985.38
# The Mean Square Error for b0= 9 b1= 10 is:  175190327046190.22
# The Mean Square Error for b0= 9 b1= 10 is:  175170739870142.75
# The Mean Square Error for b0= 9 b1= 10 is:  175151170394600.53
# The Mean Square Error for b0= 9 b1= 10 is:  175131595419103.9
# The Mean Square Error for b0= 9 b1= 10 is:  175112032954099.6
# The Mean Square Error for b0= 9 b1= 10 is:  175092464978018.62
# The Mean Square Error for b0= 9 b1= 10 is:  175072902850271.03
# The Mean Square Error for b0= 9 b1= 10 is:  175053345259537.9
# The Mean Square Error for b0= 9 b1= 10 is:  175033797376332.06
# The Mean Square Error for b0= 9 b1= 10 is:  175014263725820.6
# The Mean Square Error for b0= 9 b1= 10 is:  174994731584884.0
# The Mean Square Error for b0= 9 b1= 10 is:  174975232271329.66
# The Mean Square Error for b0= 9 b1= 10 is:  174955734146782.72
# The Mean Square Error for b0= 9 b1= 10 is:  174936265043086.22
# The Mean Square Error for b0= 9 b1= 10 is:  174916795721352.56
# The Mean Square Error for b0= 9 b1= 10 is:  174897344638524.2
# The Mean Square Error for b0= 9 b1= 10 is:  174877904663916.72
# The Mean Square Error for b0= 9 b1= 10 is:  174858499120517.22
# The Mean Square Error for b0= 9 b1= 10 is:  174839086982792.22
# The Mean Square Error for b0= 9 b1= 10 is:  174819669934495.53
# The Mean Square Error for b0= 9 b1= 10 is:  174800285547324.3
# The Mean Square Error for b0= 9 b1= 10 is:  174780894372603.5
# The Mean Square Error for b0= 9 b1= 10 is:  174761533150048.56
# The Mean Square Error for b0= 9 b1= 10 is:  174742174837193.25
